# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import gc
import matplotlib.pyplot as plt
import seaborn as sns
import time
import sys
import math
import re
import regex
import nltk 
from  nltk.corpus import stopwords
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

# %matplotlib inline
pal = sns.color_palette()
corpus = []
word_set = set()

lics = pd.read_csv('./input/licitacoes/licitacoes_2016_2017.csv', dtype={'FornecedorDocumento': object})
#lc_recent.head()

# %%
def preprocessing(raw):
    if str(raw) == 'nan':
        return ""
    try:
        # 1. Remove non-letters
        raw = regex.sub("[^\p{Latin}]"," ", raw, re.UNICODE)

        # 2. Convert words to lower case and split them
        raw = [(re.sub(r'((?<!\d)\.(?!\d))|((?<!\d)\:(?!\d))', '', word)).replace(',','') for word in raw.lower().split() if len(word) > 1]
        #raw = raw.lower().split()
        #raw = re.findall(r'\w+|[.]+', raw.lower())

        # 3. Remove stop words (false by default)
        stops = set(stopwords.words("portuguese"))
        #wordlist = nltk.word_tokenize(raw)        
        raw = [w for w in raw if not w in stops]
    except:
        print("Unexpected error:", sys.exc_info())
        
    return raw

# %%
stops

# %%
# Doc2Vec
def custom_Doc2Vec(taggeddocs):
    # Building the model
    model = Doc2Vec(taggeddocs, dm=0, alpha=0.025, size=20, min_alpha=0.025, min_count=0)
    start = time.perf_counter()
    print('Started Training')

    # Training
    total_epochs = 50
    total_docs = len(taggeddocs)
    for epoch in range(total_epochs):
        started_epoch = time.time()
        t0 = time.perf_counter()
        if epoch % 10 == 0:
            print("Started Epoch %d" % (epoch + 1))
        model.train(taggeddocs, total_examples=total_epochs, epochs=total_epochs)
        model.alpha -= 0.002 # decrease the learning rate
        model.min_alpha = model.alpha # fix the learning rate, no decay
        t1 = time.perf_counter()
        print("Epoch %d in: " % (epoch + 1), "%.3f seconds" % (t1-t0))
    
    end = time.perf_counter()
    print('Finished Training in: ', "%.3f seconds" % (end-start))
    
    return model

# %%
taggeddocs = []
for lic in lics.values:
    licx = preprocessing(lic[7])
    if len(licx) > 0:
        doc = TaggedDocument(words=licx, tags=[lic[0]])
        taggeddocs.append(doc)

# %%
model = custom_Doc2Vec(taggeddocs)
# Out:
# Started Training
# Started Epoch 1
# Epoch 1 in:  39.297 seconds
# Epoch 2 in:  37.323 seconds
# Epoch 3 in:  34.578 seconds
# Epoch 4 in:  35.671 seconds
# Epoch 5 in:  37.297 seconds
# Epoch 6 in:  33.139 seconds
# Epoch 7 in:  31.139 seconds
# Epoch 8 in:  32.175 seconds
# Epoch 9 in:  31.711 seconds
# Epoch 10 in:  33.254 seconds
# Started Epoch 11
# Epoch 11 in:  37.824 seconds
# Epoch 12 in:  39.381 seconds
# Epoch 13 in:  38.173 seconds
# Epoch 14 in:  39.419 seconds
# Epoch 15 in:  43.309 seconds
# Epoch 16 in:  40.349 seconds
# Epoch 17 in:  43.636 seconds
# Epoch 18 in:  37.656 seconds
# Epoch 19 in:  47.222 seconds
# Epoch 20 in:  42.227 seconds
# Started Epoch 21
# Epoch 21 in:  46.720 seconds
# Epoch 22 in:  38.624 seconds
# Epoch 23 in:  39.711 seconds
# Epoch 24 in:  42.739 seconds
# Epoch 25 in:  42.945 seconds
# Epoch 26 in:  37.648 seconds
# Epoch 27 in:  37.582 seconds
# Epoch 28 in:  42.287 seconds
# Epoch 29 in:  36.542 seconds
# Epoch 30 in:  33.751 seconds
# Started Epoch 31
# Epoch 31 in:  43.966 seconds
# Epoch 32 in:  31.942 seconds
# Epoch 33 in:  31.534 seconds
# Epoch 34 in:  32.298 seconds
# Epoch 35 in:  31.703 seconds
# Epoch 36 in:  33.610 seconds
# Epoch 37 in:  32.014 seconds
# Epoch 38 in:  38.435 seconds
# Epoch 39 in:  34.458 seconds
# Epoch 40 in:  31.783 seconds
# Started Epoch 41
# Epoch 41 in:  31.404 seconds
# Epoch 42 in:  31.305 seconds
# Epoch 43 in:  32.736 seconds
# Epoch 44 in:  38.106 seconds
# Epoch 45 in:  32.595 seconds
# Epoch 46 in:  31.838 seconds
# Epoch 47 in:  35.487 seconds
# Epoch 48 in:  32.356 seconds
# Epoch 49 in:  36.306 seconds
# Epoch 50 in:  43.941 seconds
# Finished Training in:  1841.207 seconds

# %%
text1 = preprocessing(lics['objeto'].tolist()[0])
text2 = preprocessing(lics['objeto'].tolist()[9080])
# Comput Cosine distances
similarity_vec = model.n_similarity(text1, text2)
print('Similarity Index: {:4.2f} %'.format(similarity_vec*100))

# %%
model.save('./output/lics_model.doc2vec')

# %%
t0 = time.perf_counter()
licitacoes = {}
for lic1 in lics.values:
    lic1x = preprocessing(lic1[7])
    if len(lic1x) > 0:
        for sim in model.docvecs.most_similar([lic1[0]], topn=50):
            if sim[1] >= 0.9:
                if str(lic1[0]) not in licitacoes:
                    licitacoes[str(lic1[0])] = []
                licitacoes[str(lic1[0])].append({'id': sim[0], 'sim': sim[1]})
    if lic1[0] % 1000 == 0:
        t1 = time.perf_counter()
        print("Done %d in: " % (lic1[0] + 1), "%.3f seconds" % (t1-t0))
        t0 = time.perf_counter()
# Out:
# Done 1 in:  0.266 seconds
# Done 1001 in:  1.038 seconds
# Done 2001 in:  1.070 seconds
# Done 3001 in:  1.082 seconds
# Done 4001 in:  1.329 seconds
# Done 5001 in:  1.176 seconds
# Done 6001 in:  1.054 seconds
# Done 7001 in:  1.073 seconds
# Done 8001 in:  1.084 seconds
# Done 9001 in:  2.601 seconds
# Done 10001 in:  1.221 seconds
# Done 11001 in:  1.073 seconds

# %%
lics['sim'] = ''
lics['user_id'] = '1234'
for index, row in lics.iterrows():
    if str(index) in licitacoes:
        lics.set_value(index,'sim',licitacoes[str(index)])

lics.to_csv('./output/licitacoes_2016_2017.csv', index=False, encoding='utf-8')
lics.head()
# Out:
#    index                                   Orgao Retranca         Modalidade  \
# 0      0                                EDUCAÇÃO  EGAAADM  PREGÃO ELETRÔNICO
# 1      1  HOSPITAL DO SERVIDOR PÚBLICO MUNICIPAL  ELAAADM  PREGÃO ELETRÔNICO
# 2      2  HOSPITAL DO SERVIDOR PÚBLICO MUNICIPAL  ELBCADM    INEXIGIBILIDADE
# 3      3             TRABALHO E EMPREENDEDORISMO  EBNAADM  PREGÃO PRESENCIAL
# 4      4                                   SAÚDE  EPAAADM  PREGÃO ELETRÔNICO
#
#           textbox17         textbox19                       Número_Licitação  \
# 0       14/SME/2015  2014-0.286.506-2  EXTRATO DE CONTRATO / NOTA DE EMPENHO
# 1          145/2015  2015-0.223.234-7  EXTRATO DE CONTRATO / NOTA DE EMPENHO
# 2  2015-0.296.519-0  2015-0.296.519-0  EXTRATO DE CONTRATO / NOTA DE EMPENHO
# 3      11/SDTE/2013  2013-0.258.474-6                  EXTRATO DE ADITAMENTO
# 4    349/2015-SMS.G  2015-0.265.139-0    EXTRATO DE ATA DE REGISTRO DE PREÇO
#
#                                               objeto DataPublicaçãoExtrato  \
# 0  REGISTRO DE PREÇOS PARA AQUISIÇÃO DE FÓRMULA I...              4/3/2016
# 1                 FORMULAÇÕES MAGISTRAIS E OFICINAIS              4/3/2016
# 2                                         MANUTENÇAO              4/3/2016
# 3  CONTRATAÇAO DE EMPRESA ESPECIALIZADA NA PRESTA...              4/3/2016
# 4  Registro de preços para o fornecimento de CAIX...              4/3/2016
#
#                                           Fornecedor FornecedorTipo  \
# 0  MARTINUCI COMÉRCIO E REPRESENTAÇÕES DE PRODUTO...             PJ
# 1                   PIRES DE CAMPOS & CIA LTDA - EPP             PJ
# 2            LASER LAB COM. ASSISTÊNCIA TÉCNICA LTDA             PJ
# 3                  ARK TEC GUARDA DE DOCUMENTOS LTDA             PJ
# 4                           PONTUAL COMERCIAL EIRELI             PJ
#
#   FornecedorDocumento DataAssinaturaExtrato  ValidadeExtrato  \
# 0      18097272000117            24/02/2016              4.0
# 1      45516507000130            29/02/2016             12.0
# 2      72682263000139            22/02/2016             12.0
# 3      65689895000169             11/2/2016             12.0
# 4       1854654000145            26/02/2016             12.0
#
#   TipoValidadeExtrato ValorContrato      NúmeroContrato  \
# 0               Meses    942.955,20   10/SME/CODAE/2016
# 1               Meses     55.944,00            078/2016
# 2               Meses     27.948,00            077/2016
# 3               Meses     43.973,48  001/2014/PMSP/SDTE
# 4               Meses    886.002,00      084/2016-SMS.G
#
#                                                  sim user_id
# 0  [{'id': 2594, 'sim': 0.9812979698181152}, {'id...    1234
# 1  [{'id': 7685, 'sim': 0.9862677454948425}, {'id...    1234
# 2  [{'id': 8584, 'sim': 0.9657570123672485}, {'id...    1234
# 3                                                       1234
# 4                                                       1234

# %%
import boto
from csv import reader

MY_ACCESS_KEY_ID = 'AKIAJNUAMOKDMGZFQK6A'
MY_SECRET_ACCESS_KEY = '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'


def do_batch_write(items, table_name, dynamodb_table, dynamodb_conn):
    batch_list = dynamodb_conn.new_batch_write_list()
    batch_list.add_batch(dynamodb_table, puts=items)
    while True:
        response = dynamodb_conn.batch_write_item(batch_list)
        unprocessed = response.get('UnprocessedItems', None)
        if not unprocessed:
            break
        batch_list = dynamodb_conn.new_batch_write_list()
        unprocessed_list = unprocessed[table_name]
        items = []
        for u in unprocessed_list:
            item_attr = u['PutRequest']['Item']
            item = dynamodb_table.new_item(
                    attrs=item_attr
            )
            items.append(item)
        batch_list.add_batch(dynamodb_table, puts=items)


def import_csv_to_dynamodb(table_name, csv_file_name, colunm_names,     column_types):
    dynamodb_conn =     boto.connect_dynamodb(aws_access_key_id=MY_ACCESS_KEY_ID, aws_secret_access_key=MY_SECRET_ACCESS_KEY)
    dynamodb_table = dynamodb_conn.get_table(table_name)     
    BATCH_COUNT = 25 # 25 is the maximum batch size for Amazon DynamoDB

    items = []

    count = 0
    csv_file = open(csv_file_name, 'r')
    for cur_line in reader(csv_file):
        count += 1

        row = {}
        for colunm_number, colunm_name in enumerate(colunm_names):
            row[colunm_name] = column_types[colunm_number]    (cur_line[colunm_number])
        
        if row['contract_id'] != 'index':

            if len(row['sim']) == 0:
                del row['sim']
            if len(row['NúmeroContrato']) == 0:
                del row['NúmeroContrato']
            if len(row['Fornecedor']) == 0:
                del row['Fornecedor']
            if len(row['FornecedorDocumento']) == 0:
                del row['FornecedorDocumento']
            if len(row['ValidadeExtrato']) == 0:
                del row['ValidadeExtrato']
            if len(row['TipoValidadeExtrato']) == 0:
                del row['TipoValidadeExtrato']
            if len(row['ValorContrato']) == 0:
                del row['ValorContrato']
                
            if len(row['DataAssinaturaExtrato']) == 0:
                del row['DataAssinaturaExtrato']
            if len(row['DataPublicaçãoExtrato']) == 0:
                del row['DataPublicaçãoExtrato']
            if len(row['FornecedorTipo']) == 0:
                del row['FornecedorTipo']

            if len(row['Orgao']) == 0:
                del row['Orgao']
            if len(row['Retranca']) == 0:
                del row['Retranca']
            if len(row['textbox17']) == 0:
                del row['textbox17']
            if len(row['textbox19']) == 0:
                del row['textbox19']
            if len(row['Modalidade']) == 0:
                del row['Modalidade']
            if len(row['Número_Licitação']) == 0:
                del row['Número_Licitação']
            if len(row['objeto']) == 0:
                del row['objeto']
                
                #print(row)    
            item = dynamodb_table.new_item(attrs=row)
            items.append(item)
            if count % BATCH_COUNT == 0:
                #print ('batch write start ... ', 
                do_batch_write(items, table_name, dynamodb_table, dynamodb_conn)
                items = []
                print ('batch done! (row number: ' + str(count) + ')')

    # flush remaining items, if any
    if len(items) > 0: 
        do_batch_write(items, table_name, dynamodb_table, dynamodb_conn)


    csv_file.close() 


def main():
    '''
    Demonstration of the use of import_csv_to_dynamodb()
    We assume the existence of a table named `test_persons`, with
    - Last_name as primary hash key (type: string)
    - First_name as primary range key (type: string)
    '''
    colunm_names = 'contract_id Orgao Retranca Modalidade textbox17 textbox19 Número_Licitação objeto DataPublicaçãoExtrato Fornecedor FornecedorTipo FornecedorDocumento DataAssinaturaExtrato ValidadeExtrato TipoValidadeExtrato ValorContrato NúmeroContrato sim user_id'.split()
    table_name = 'contracts'
    csv_file_name = './output/licitacoes_2016_2017.csv'
    column_types = [str, str, str, str, str, str, str, str, str, str, str, str, str, str, str, str, str, str, str]
    import_csv_to_dynamodb(table_name, csv_file_name, colunm_names, column_types)


if __name__ == "__main__":
    main()
    #cProfile.run('main()') # if you want to do some profiling
# Out:
# batch done! (row number: 25)
# batch done! (row number: 50)
# batch done! (row number: 75)
# batch done! (row number: 100)
# batch done! (row number: 125)
# batch done! (row number: 150)
# batch done! (row number: 175)
# batch done! (row number: 200)
# batch done! (row number: 225)
# batch done! (row number: 250)
# batch done! (row number: 275)
# batch done! (row number: 300)
# batch done! (row number: 325)
# batch done! (row number: 350)
# batch done! (row number: 375)
# batch done! (row number: 400)
# batch done! (row number: 425)
# batch done! (row number: 450)
# batch done! (row number: 475)
# batch done! (row number: 500)
# batch done! (row number: 525)
# batch done! (row number: 550)
# batch done! (row number: 575)
# batch done! (row number: 600)
# batch done! (row number: 625)
# batch done! (row number: 650)
# batch done! (row number: 675)
# batch done! (row number: 700)
# batch done! (row number: 725)
# batch done! (row number: 750)
# batch done! (row number: 775)
# batch done! (row number: 800)
# batch done! (row number: 825)
# batch done! (row number: 850)
# batch done! (row number: 875)
# batch done! (row number: 900)
# batch done! (row number: 925)
# batch done! (row number: 950)
# batch done! (row number: 975)
# batch done! (row number: 1000)
# batch done! (row number: 1025)
# batch done! (row number: 1050)
# batch done! (row number: 1075)
# batch done! (row number: 1100)
# batch done! (row number: 1125)
# batch done! (row number: 1150)
# batch done! (row number: 1175)
# batch done! (row number: 1200)
# batch done! (row number: 1225)
# batch done! (row number: 1250)
# batch done! (row number: 1275)
# batch done! (row number: 1300)
# batch done! (row number: 1325)
# batch done! (row number: 1350)
# batch done! (row number: 1375)
# batch done! (row number: 1400)
# batch done! (row number: 1425)
# batch done! (row number: 1450)
# batch done! (row number: 1475)
# batch done! (row number: 1500)
# batch done! (row number: 1525)
# batch done! (row number: 1550)
# batch done! (row number: 1575)
# batch done! (row number: 1600)
# batch done! (row number: 1625)
# batch done! (row number: 1650)
# batch done! (row number: 1675)
# batch done! (row number: 1700)
# batch done! (row number: 1725)
# batch done! (row number: 1750)
# batch done! (row number: 1775)
# batch done! (row number: 1800)
# batch done! (row number: 1825)
# batch done! (row number: 1850)
# batch done! (row number: 1875)
# batch done! (row number: 1900)
# batch done! (row number: 1925)
# batch done! (row number: 1950)
# batch done! (row number: 1975)
# batch done! (row number: 2000)
# batch done! (row number: 2025)
# batch done! (row number: 2050)
# batch done! (row number: 2075)
# batch done! (row number: 2100)
# batch done! (row number: 2125)
# batch done! (row number: 2150)
# batch done! (row number: 2175)
# batch done! (row number: 2200)
# batch done! (row number: 2225)
# batch done! (row number: 2250)
# batch done! (row number: 2275)
# batch done! (row number: 2300)
# batch done! (row number: 2325)
# batch done! (row number: 2350)
# batch done! (row number: 2375)
# batch done! (row number: 2400)
# batch done! (row number: 2425)
# batch done! (row number: 2450)
# batch done! (row number: 2475)
# batch done! (row number: 2500)
# batch done! (row number: 2525)
# batch done! (row number: 2550)
# batch done! (row number: 2575)
# batch done! (row number: 2600)
# batch done! (row number: 2625)
# batch done! (row number: 2650)
# batch done! (row number: 2675)
# batch done! (row number: 2700)
# batch done! (row number: 2725)
# batch done! (row number: 2750)
# batch done! (row number: 2775)
# batch done! (row number: 2800)
# batch done! (row number: 2825)
# batch done! (row number: 2850)
# batch done! (row number: 2875)
# batch done! (row number: 2900)
# batch done! (row number: 2925)
# batch done! (row number: 2950)
# batch done! (row number: 2975)
# batch done! (row number: 3000)
# batch done! (row number: 3025)
# batch done! (row number: 3050)
# batch done! (row number: 3075)
# batch done! (row number: 3100)
# batch done! (row number: 3125)
# batch done! (row number: 3150)
# batch done! (row number: 3175)
# batch done! (row number: 3200)
# batch done! (row number: 3225)
# batch done! (row number: 3250)
# batch done! (row number: 3275)
# batch done! (row number: 3300)
# batch done! (row number: 3325)
# batch done! (row number: 3350)
# batch done! (row number: 3375)
# batch done! (row number: 3400)
# batch done! (row number: 3425)
# batch done! (row number: 3450)
# batch done! (row number: 3475)
# batch done! (row number: 3500)
# batch done! (row number: 3525)
# batch done! (row number: 3550)
# batch done! (row number: 3575)
# batch done! (row number: 3600)
# batch done! (row number: 3625)
# batch done! (row number: 3650)
# batch done! (row number: 3675)
# batch done! (row number: 3700)
# batch done! (row number: 3725)
# batch done! (row number: 3750)
# batch done! (row number: 3775)
# batch done! (row number: 3800)
# batch done! (row number: 3825)
# batch done! (row number: 3850)
# batch done! (row number: 3875)
# batch done! (row number: 3900)
# batch done! (row number: 3925)
# batch done! (row number: 3950)
# batch done! (row number: 3975)
# batch done! (row number: 4000)
# batch done! (row number: 4025)
# batch done! (row number: 4050)
# batch done! (row number: 4075)
# batch done! (row number: 4100)
# batch done! (row number: 4125)
# batch done! (row number: 4150)
# batch done! (row number: 4175)
# batch done! (row number: 4200)
# batch done! (row number: 4225)
# batch done! (row number: 4250)
# batch done! (row number: 4275)
# batch done! (row number: 4300)
# batch done! (row number: 4325)
# batch done! (row number: 4350)
# batch done! (row number: 4375)
# batch done! (row number: 4400)
# batch done! (row number: 4425)
# batch done! (row number: 4450)
# batch done! (row number: 4475)
# batch done! (row number: 4500)
# batch done! (row number: 4525)
# batch done! (row number: 4550)
# batch done! (row number: 4575)
# batch done! (row number: 4600)
# batch done! (row number: 4625)
# batch done! (row number: 4650)
# batch done! (row number: 4675)
# batch done! (row number: 4700)
# batch done! (row number: 4725)
# batch done! (row number: 4750)
# batch done! (row number: 4775)
# batch done! (row number: 4800)
# batch done! (row number: 4825)
# batch done! (row number: 4850)
# batch done! (row number: 4875)
# batch done! (row number: 4900)
# batch done! (row number: 4925)
# batch done! (row number: 4950)
# batch done! (row number: 4975)
# batch done! (row number: 5000)
# batch done! (row number: 5025)
# batch done! (row number: 5050)
# batch done! (row number: 5075)
# batch done! (row number: 5100)
# batch done! (row number: 5125)
# batch done! (row number: 5150)
# batch done! (row number: 5175)
# batch done! (row number: 5200)
# batch done! (row number: 5225)
# batch done! (row number: 5250)
# batch done! (row number: 5275)
# batch done! (row number: 5300)
# batch done! (row number: 5325)
# batch done! (row number: 5350)
# batch done! (row number: 5375)
# batch done! (row number: 5400)
# batch done! (row number: 5425)
# batch done! (row number: 5450)
# batch done! (row number: 5475)
# batch done! (row number: 5500)
# batch done! (row number: 5525)
# batch done! (row number: 5550)
# batch done! (row number: 5575)
# batch done! (row number: 5600)
# batch done! (row number: 5625)
# batch done! (row number: 5650)
# batch done! (row number: 5675)
# batch done! (row number: 5700)
# batch done! (row number: 5725)
# batch done! (row number: 5750)
# batch done! (row number: 5775)
# batch done! (row number: 5800)
# batch done! (row number: 5825)
# batch done! (row number: 5850)
# batch done! (row number: 5875)
# batch done! (row number: 5900)
# batch done! (row number: 5925)
# batch done! (row number: 5950)
# batch done! (row number: 5975)
# batch done! (row number: 6000)
# batch done! (row number: 6025)
# batch done! (row number: 6050)
# batch done! (row number: 6075)
# batch done! (row number: 6100)
# batch done! (row number: 6125)
# batch done! (row number: 6150)
# batch done! (row number: 6175)
# batch done! (row number: 6200)
# batch done! (row number: 6225)
# batch done! (row number: 6250)
# batch done! (row number: 6275)
# batch done! (row number: 6300)
# batch done! (row number: 6325)
# batch done! (row number: 6350)
# batch done! (row number: 6375)
# batch done! (row number: 6400)
# batch done! (row number: 6425)
# batch done! (row number: 6450)
# batch done! (row number: 6475)
# batch done! (row number: 6500)
# batch done! (row number: 6525)
# batch done! (row number: 6550)
# batch done! (row number: 6575)
# batch done! (row number: 6600)
# batch done! (row number: 6625)
# batch done! (row number: 6650)
# batch done! (row number: 6675)
# batch done! (row number: 6700)
# batch done! (row number: 6725)
# batch done! (row number: 6750)
# batch done! (row number: 6775)
# batch done! (row number: 6800)
# batch done! (row number: 6825)
# batch done! (row number: 6850)
# batch done! (row number: 6875)
# batch done! (row number: 6900)
# batch done! (row number: 6925)
# batch done! (row number: 6950)
# batch done! (row number: 6975)
# batch done! (row number: 7000)
# batch done! (row number: 7025)
# batch done! (row number: 7050)
# batch done! (row number: 7075)
# batch done! (row number: 7100)
# batch done! (row number: 7125)
# batch done! (row number: 7150)
# batch done! (row number: 7175)
# batch done! (row number: 7200)
# batch done! (row number: 7225)
# batch done! (row number: 7250)
# batch done! (row number: 7275)
# batch done! (row number: 7300)
# batch done! (row number: 7325)
# batch done! (row number: 7350)
# batch done! (row number: 7375)
# batch done! (row number: 7400)
# batch done! (row number: 7425)
# batch done! (row number: 7450)
# batch done! (row number: 7475)
# batch done! (row number: 7500)
# batch done! (row number: 7525)
# batch done! (row number: 7550)
# batch done! (row number: 7575)
# batch done! (row number: 7600)
# batch done! (row number: 7625)
# batch done! (row number: 7650)
# batch done! (row number: 7675)
# batch done! (row number: 7700)
# batch done! (row number: 7725)
# batch done! (row number: 7750)
# batch done! (row number: 7775)
# batch done! (row number: 7800)
# batch done! (row number: 7825)
# batch done! (row number: 7850)
# batch done! (row number: 7875)
# batch done! (row number: 7900)
# batch done! (row number: 7925)
# batch done! (row number: 7950)
# batch done! (row number: 7975)
# batch done! (row number: 8000)
# batch done! (row number: 8025)
# batch done! (row number: 8050)
# batch done! (row number: 8075)
# batch done! (row number: 8100)
# batch done! (row number: 8125)
# batch done! (row number: 8150)
# batch done! (row number: 8175)
# batch done! (row number: 8200)
# batch done! (row number: 8225)
# batch done! (row number: 8250)
# batch done! (row number: 8275)
# batch done! (row number: 8300)
# batch done! (row number: 8325)
# batch done! (row number: 8350)
# batch done! (row number: 8375)
# batch done! (row number: 8400)
# batch done! (row number: 8425)
# batch done! (row number: 8450)
# batch done! (row number: 8475)
# batch done! (row number: 8500)
# batch done! (row number: 8525)
# batch done! (row number: 8550)
# batch done! (row number: 8575)
# batch done! (row number: 8600)
# batch done! (row number: 8625)
# batch done! (row number: 8650)
# batch done! (row number: 8675)
# batch done! (row number: 8700)
# batch done! (row number: 8725)
# batch done! (row number: 8750)
# batch done! (row number: 8775)
# batch done! (row number: 8800)
# batch done! (row number: 8825)
# batch done! (row number: 8850)
# batch done! (row number: 8875)
# batch done! (row number: 8900)
# batch done! (row number: 8925)
# batch done! (row number: 8950)
# batch done! (row number: 8975)
# batch done! (row number: 9000)
# batch done! (row number: 9025)
# batch done! (row number: 9050)
# batch done! (row number: 9075)
# batch done! (row number: 9100)
# batch done! (row number: 9125)
# batch done! (row number: 9150)
# batch done! (row number: 9175)
# batch done! (row number: 9200)
# batch done! (row number: 9225)
# batch done! (row number: 9250)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-225-f6bcfb144c45> in <module>()
#     113
#     114 if __name__ == "__main__":
# --> 115     main()
#     116     #cProfile.run('main()') # if you want to do some profiling
#
# <ipython-input-225-f6bcfb144c45> in main()
#     109     csv_file_name = './output/licitacoes_2016_2017.csv'
#     110     column_types = [str, str, str, str, str, str, str, str, str, str, str, str, str, str, str, str, str, str, str]
# --> 111     import_csv_to_dynamodb(table_name, csv_file_name, colunm_names, column_types)
#     112
#     113
#
# <ipython-input-225-f6bcfb144c45> in import_csv_to_dynamodb(table_name, csv_file_name, colunm_names, column_types)
#      86             if count % BATCH_COUNT == 0:
#      87                 #print ('batch write start ... ',
# ---> 88                 do_batch_write(items, table_name, dynamodb_table, dynamodb_conn)
#      89                 items = []
#      90                 print ('batch done! (row number: ' + str(count) + ')')
#
# <ipython-input-225-f6bcfb144c45> in do_batch_write(items, table_name, dynamodb_table, dynamodb_conn)
#      10     batch_list.add_batch(dynamodb_table, puts=items)
#      11     while True:
# ---> 12         response = dynamodb_conn.batch_write_item(batch_list)
#      13         unprocessed = response.get('UnprocessedItems', None)
#      14         if not unprocessed:
#
# /usr/local/lib/python3.6/site-packages/boto/dynamodb/layer2.py in batch_write_item(self, batch_list)
#     521         request_items = batch_list.to_dict()
#     522         return self.layer1.batch_write_item(request_items,
# --> 523                                             object_hook=self.dynamizer.decode)
#     524
#     525     def put_item(self, item, expected_value=None, return_values=None):
#
# /usr/local/lib/python3.6/site-packages/boto/dynamodb/layer1.py in batch_write_item(self, request_items, object_hook)
#     343         json_input = json.dumps(data)
#     344         return self.make_request('BatchWriteItem', json_input,
# --> 345                                  object_hook=object_hook)
#     346
#     347     def put_item(self, table_name, item,
#
# /usr/local/lib/python3.6/site-packages/boto/dynamodb/layer1.py in make_request(self, action, body, object_hook)
#     117         response = self._mexe(http_request, sender=None,
#     118                               override_num_retries=self.NumberRetries,
# --> 119                               retry_handler=self._retry_handler)
#     120         elapsed = (time.time() - start) * 1000
#     121         request_id = response.getheader('x-amzn-RequestId')
#
# /usr/local/lib/python3.6/site-packages/boto/connection.py in _mexe(self, request, sender, override_num_retries, retry_handler)
#     942                     connection.request(request.method, request.path,
#     943                                        request.body, request.headers)
# --> 944                     response = connection.getresponse()
#     945                 boto.log.debug('Response headers: %s' % response.getheaders())
#     946                 location = response.getheader('location')
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1000                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1001                   self.__class__)
# -> 1002             return self.read(nbytes, buffer)
#    1003         else:
#    1004             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     863             raise ValueError("Read on closed or unwrapped SSL socket.")
#     864         try:
# --> 865             return self._sslobj.read(len, buffer)
#     866         except SSLError as x:
#     867             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/local/Cellar/python3/3.6.0/Frameworks/Python.framework/Versions/3.6/lib/python3.6/ssl.py in read(self, len, buffer)
#     623         """
#     624         if buffer is not None:
# --> 625             v = self._sslobj.read(len, buffer)
#     626         else:
#     627             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
